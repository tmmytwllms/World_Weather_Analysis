# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
#Get a range of latitutdes and longitudes
lats=np.random.uniform(-90.000,90.000,size=2000)
lngs=np.random.uniform(-180.000,180.000,size=2000)
lats_lngs=zip(lats,lngs)
lats_lngs

# %%
#Convert the zip to a list
coordinates=list(lats_lngs)

# %%
#Create a list to hold the cities for assigned coordinates
cities=[]
#Loop through the coordinates
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#Import datetime module
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + city

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Weather":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | cockburn town
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | mount isa
# Processing Record 5 of Set 1 | vaitape
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | cherskiy
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | fortuna
# Processing Record 11 of Set 1 | balykshi
# Processing Record 12 of Set 1 | havelock
# Processing Record 13 of Set 1 | xiangxiang
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | estelle
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | caracollo
# Processing Record 20 of Set 1 | storm lake
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | susangerd
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | poum
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | samarai
# Processing Record 28 of Set 1 | pacific grove
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | camacha
# Processing Record 31 of Set 1 | neya
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | yar-sale
# Processing Record 36 of Set 1 | shaoxing
# Processing Record 37 of Set 1 | vila
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | hay river
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | nchelenge
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | alakurtti
# Processing Record 47 of Set 1 | synya
# Processing Record 48 of Set 1 | mayo
# Processing Record 49 of Set 1 | narasannapeta
# Processing Record 50 of Set 1 | east london
# Processing Record 1 of Set 2 | fiche
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | fokino
# Processing Record 4 of Set 2 | gardenstown
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | lesnikovo
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | rehoboth
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | porto novo
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | bethel
# Processing Record 13 of Set 2 | ponta do sol
# Processing Record 14 of Set 2 | spas-demensk
# Processing Record 15 of Set 2 | xai-xai
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | pangnirtung
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | nanakuli
# Processing Record 22 of Set 2 | belmonte
# Processing Record 23 of Set 2 | tulagi
# Processing Record 24 of Set 2 | austin
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | nouadhibou
# Processing Record 27 of Set 2 | dok kham tai
# Processing Record 28 of Set 2 | lorengau
# Processing Record 29 of Set 2 | trebinje
# Processing Record 30 of Set 2 | adamas
# Processing Record 31 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 2 | raga
# Processing Record 33 of Set 2 | iberia
# Processing Record 34 of Set 2 | kurchum
# Processing Record 35 of Set 2 | mucurapo
# Processing Record 36 of Set 2 | hambantota
# Processing Record 37 of Set 2 | dillon
# Processing Record 38 of Set 2 | predivinsk
# Processing Record 39 of Set 2 | gewane
# Processing Record 40 of Set 2 | coihaique
# Processing Record 41 of Set 2 | saskylakh
# Processing Record 42 of Set 2 | auki
# Processing Record 43 of Set 2 | jhalida
# Processing Record 44 of Set 2 | comodoro rivadavia
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | namibe
# Processing Record 47 of Set 2 | sao bartolomeu de messines
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | palencia
# Processing Record 50 of Set 2 | correntina
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | duluth
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | brownwood
# Processing Record 5 of Set 3 | saquena
# Processing Record 6 of Set 3 | san quintin
# Processing Record 7 of Set 3 | forio
# Processing Record 8 of Set 3 | bambous virieux
# Processing Record 9 of Set 3 | isangel
# Processing Record 10 of Set 3 | geraldton
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | bengkulu
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | kapaa
# Processing Record 17 of Set 3 | nyurba
# Processing Record 18 of Set 3 | xining
# Processing Record 19 of Set 3 | nome
# Processing Record 20 of Set 3 | lerwick
# Processing Record 21 of Set 3 | severo-kurilsk
# Processing Record 22 of Set 3 | chachapoyas
# Processing Record 23 of Set 3 | codrington
# Processing Record 24 of Set 3 | san rafael del sur
# Processing Record 25 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 3 | zhezkazgan
# Processing Record 27 of Set 3 | skjervoy
# Processing Record 28 of Set 3 | mataura
# Processing Record 29 of Set 3 | aleksandrov gay
# Processing Record 30 of Set 3 | rio gallegos
# Processing Record 31 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 3 | sembe
# Processing Record 33 of Set 3 | cotonou
# Processing Record 34 of Set 3 | fairbanks
# Processing Record 35 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 3 | bac can
# City not found. Skipping...
# Processing Record 37 of Set 3 | henties bay
# Processing Record 38 of Set 3 | kalmunai
# Processing Record 39 of Set 3 | port elizabeth
# Processing Record 40 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 3 | changde
# Processing Record 42 of Set 3 | kabelvag
# Processing Record 43 of Set 3 | storrs
# Processing Record 44 of Set 3 | olafsvik
# Processing Record 45 of Set 3 | mildura
# Processing Record 46 of Set 3 | airai
# Processing Record 47 of Set 3 | chuy
# Processing Record 48 of Set 3 | port hardy
# Processing Record 49 of Set 3 | rocha
# Processing Record 50 of Set 3 | hami
# Processing Record 1 of Set 4 | torbay
# Processing Record 2 of Set 4 | kinshasa
# Processing Record 3 of Set 4 | mbanza-ngungu
# Processing Record 4 of Set 4 | agadez
# Processing Record 5 of Set 4 | arlit
# Processing Record 6 of Set 4 | macamic
# Processing Record 7 of Set 4 | saint george
# Processing Record 8 of Set 4 | sadovoye
# Processing Record 9 of Set 4 | tiksi
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 4 | pereslavl-zalesskiy
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | garowe
# Processing Record 15 of Set 4 | metkovic
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | santa rosa
# Processing Record 18 of Set 4 | saldanha
# Processing Record 19 of Set 4 | antsohihy
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 4 | lasa
# Processing Record 22 of Set 4 | aripuana
# Processing Record 23 of Set 4 | muli
# Processing Record 24 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 4 | presidencia roque saenz pena
# Processing Record 26 of Set 4 | lebu
# Processing Record 27 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 4 | knysna
# Processing Record 29 of Set 4 | mao
# Processing Record 30 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 4 | hualmay
# Processing Record 32 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 4 | vardo
# Processing Record 34 of Set 4 | namtsy
# Processing Record 35 of Set 4 | rivera
# Processing Record 36 of Set 4 | lata
# Processing Record 37 of Set 4 | ranong
# Processing Record 38 of Set 4 | saint anthony
# Processing Record 39 of Set 4 | placido de castro
# Processing Record 40 of Set 4 | souillac
# Processing Record 41 of Set 4 | ponta delgada
# Processing Record 42 of Set 4 | pevek
# Processing Record 43 of Set 4 | grindavik
# Processing Record 44 of Set 4 | sola
# Processing Record 45 of Set 4 | roma
# Processing Record 46 of Set 4 | port keats
# Processing Record 47 of Set 4 | clyde river
# Processing Record 48 of Set 4 | aklavik
# Processing Record 49 of Set 4 | amapa
# Processing Record 50 of Set 4 | qaanaaq
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | avanigadda
# Processing Record 3 of Set 5 | narsaq
# Processing Record 4 of Set 5 | speightstown
# Processing Record 5 of Set 5 | avera
# Processing Record 6 of Set 5 | biak
# Processing Record 7 of Set 5 | tire
# Processing Record 8 of Set 5 | san ignacio
# Processing Record 9 of Set 5 | khani
# Processing Record 10 of Set 5 | yerbogachen
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | sao joaquim
# Processing Record 13 of Set 5 | makaryev
# Processing Record 14 of Set 5 | kargasok
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | saint-pierre
# Processing Record 17 of Set 5 | bar harbor
# Processing Record 18 of Set 5 | lisala
# Processing Record 19 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 5 | los llanos de aridane
# Processing Record 21 of Set 5 | yefira
# City not found. Skipping...
# Processing Record 22 of Set 5 | aguie
# Processing Record 23 of Set 5 | mizdah
# Processing Record 24 of Set 5 | kharp
# Processing Record 25 of Set 5 | puerto ayora
# Processing Record 26 of Set 5 | yenagoa
# Processing Record 27 of Set 5 | big rapids
# Processing Record 28 of Set 5 | hasaki
# Processing Record 29 of Set 5 | salalah
# Processing Record 30 of Set 5 | namie
# Processing Record 31 of Set 5 | dikson
# Processing Record 32 of Set 5 | ambilobe
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | georgetown
# Processing Record 35 of Set 5 | iskateley
# Processing Record 36 of Set 5 | ampanihy
# Processing Record 37 of Set 5 | kahului
# Processing Record 38 of Set 5 | elmina
# Processing Record 39 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 40 of Set 5 | coahuayana
# Processing Record 41 of Set 5 | nemuro
# Processing Record 42 of Set 5 | meulaboh
# Processing Record 43 of Set 5 | usinsk
# Processing Record 44 of Set 5 | gravdal
# Processing Record 45 of Set 5 | katsuura
# Processing Record 46 of Set 5 | gulabpura
# Processing Record 47 of Set 5 | kambove
# Processing Record 48 of Set 5 | ayan
# Processing Record 49 of Set 5 | pimentel
# Processing Record 50 of Set 5 | guiyang
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | baykit
# Processing Record 3 of Set 6 | kamenka
# Processing Record 4 of Set 6 | omboue
# Processing Record 5 of Set 6 | carlsbad
# Processing Record 6 of Set 6 | kutum
# Processing Record 7 of Set 6 | general pico
# Processing Record 8 of Set 6 | ucluelet
# Processing Record 9 of Set 6 | san jeronimo
# Processing Record 10 of Set 6 | salinas
# Processing Record 11 of Set 6 | cabo san lucas
# Processing Record 12 of Set 6 | deputatskiy
# Processing Record 13 of Set 6 | fuente palmera
# Processing Record 14 of Set 6 | americo brasiliense
# Processing Record 15 of Set 6 | saint-philippe
# Processing Record 16 of Set 6 | prachuap khiri khan
# Processing Record 17 of Set 6 | northam
# Processing Record 18 of Set 6 | abeche
# Processing Record 19 of Set 6 | shirokiy
# Processing Record 20 of Set 6 | vrangel
# Processing Record 21 of Set 6 | darlawn
# Processing Record 22 of Set 6 | sumkino
# Processing Record 23 of Set 6 | kodiak
# Processing Record 24 of Set 6 | valasske klobouky
# Processing Record 25 of Set 6 | azul
# Processing Record 26 of Set 6 | brae
# Processing Record 27 of Set 6 | kuytun
# Processing Record 28 of Set 6 | kurikka
# Processing Record 29 of Set 6 | coxim
# Processing Record 30 of Set 6 | korla
# Processing Record 31 of Set 6 | bonthe
# Processing Record 32 of Set 6 | sao filipe
# Processing Record 33 of Set 6 | hazleton
# Processing Record 34 of Set 6 | faya
# Processing Record 35 of Set 6 | haines junction
# Processing Record 36 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 37 of Set 6 | upata
# Processing Record 38 of Set 6 | yining
# Processing Record 39 of Set 6 | sena madureira
# Processing Record 40 of Set 6 | hope
# Processing Record 41 of Set 6 | ngunguru
# Processing Record 42 of Set 6 | hamilton
# Processing Record 43 of Set 6 | sabang
# Processing Record 44 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 6 | chulman
# Processing Record 46 of Set 6 | weihe
# Processing Record 47 of Set 6 | norman wells
# Processing Record 48 of Set 6 | suleja
# Processing Record 49 of Set 6 | constantine
# Processing Record 50 of Set 6 | talnakh
# Processing Record 1 of Set 7 | tovste
# Processing Record 2 of Set 7 | registro
# Processing Record 3 of Set 7 | chino valley
# Processing Record 4 of Set 7 | asau
# Processing Record 5 of Set 7 | jumla
# Processing Record 6 of Set 7 | montepuez
# Processing Record 7 of Set 7 | pasareni
# Processing Record 8 of Set 7 | koumac
# Processing Record 9 of Set 7 | george
# Processing Record 10 of Set 7 | port hedland
# Processing Record 11 of Set 7 | chegutu
# Processing Record 12 of Set 7 | maningrida
# Processing Record 13 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 7 | at-bashi
# Processing Record 15 of Set 7 | cuamba
# Processing Record 16 of Set 7 | dunedin
# Processing Record 17 of Set 7 | quelimane
# Processing Record 18 of Set 7 | alta floresta
# Processing Record 19 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 7 | pahrump
# Processing Record 21 of Set 7 | sawakin
# Processing Record 22 of Set 7 | oranjemund
# Processing Record 23 of Set 7 | farafangana
# Processing Record 24 of Set 7 | tuktoyaktuk
# Processing Record 25 of Set 7 | adrar
# Processing Record 26 of Set 7 | gizo
# Processing Record 27 of Set 7 | tromso
# Processing Record 28 of Set 7 | nuevo progreso
# Processing Record 29 of Set 7 | consolacion del sur
# Processing Record 30 of Set 7 | timra
# Processing Record 31 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 32 of Set 7 | namatanai
# Processing Record 33 of Set 7 | esperance
# Processing Record 34 of Set 7 | afyonkarahisar
# Processing Record 35 of Set 7 | fukue
# Processing Record 36 of Set 7 | barranca
# Processing Record 37 of Set 7 | kibre mengist
# Processing Record 38 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 39 of Set 7 | dauphin
# Processing Record 40 of Set 7 | kenai
# Processing Record 41 of Set 7 | madawaska
# Processing Record 42 of Set 7 | sobolevo
# Processing Record 43 of Set 7 | boone
# Processing Record 44 of Set 7 | iroquois falls
# Processing Record 45 of Set 7 | talaya
# Processing Record 46 of Set 7 | port lincoln
# Processing Record 47 of Set 7 | dubrovnik
# Processing Record 48 of Set 7 | quang ngai
# Processing Record 49 of Set 7 | trincomalee
# Processing Record 50 of Set 7 | san gavino monreale
# Processing Record 1 of Set 8 | husavik
# Processing Record 2 of Set 8 | bandarbeyla
# Processing Record 3 of Set 8 | bauchi
# Processing Record 4 of Set 8 | beloha
# Processing Record 5 of Set 8 | karonga
# Processing Record 6 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 8 | laguna
# Processing Record 8 of Set 8 | santa cruz
# Processing Record 9 of Set 8 | panguipulli
# Processing Record 10 of Set 8 | plauen
# Processing Record 11 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 8 | parnarama
# Processing Record 13 of Set 8 | sakaiminato
# Processing Record 14 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 8 | mogok
# Processing Record 16 of Set 8 | launceston
# Processing Record 17 of Set 8 | mehamn
# Processing Record 18 of Set 8 | yulara
# Processing Record 19 of Set 8 | lavrentiya
# Processing Record 20 of Set 8 | bilma
# Processing Record 21 of Set 8 | constitucion
# Processing Record 22 of Set 8 | raudeberg
# Processing Record 23 of Set 8 | emerald
# Processing Record 24 of Set 8 | kloulklubed
# Processing Record 25 of Set 8 | starogard gdanski
# Processing Record 26 of Set 8 | buraydah
# Processing Record 27 of Set 8 | zhigansk
# Processing Record 28 of Set 8 | olga
# Processing Record 29 of Set 8 | kendari
# Processing Record 30 of Set 8 | castro
# Processing Record 31 of Set 8 | lac-megantic
# Processing Record 32 of Set 8 | sisimiut
# Processing Record 33 of Set 8 | ballitoville
# Processing Record 34 of Set 8 | casambalangan
# Processing Record 35 of Set 8 | verkhnevilyuysk
# Processing Record 36 of Set 8 | peterhead
# Processing Record 37 of Set 8 | bara
# Processing Record 38 of Set 8 | chinhoyi
# Processing Record 39 of Set 8 | cap-aux-meules
# Processing Record 40 of Set 8 | belyy yar
# Processing Record 41 of Set 8 | ancud
# Processing Record 42 of Set 8 | ust-nera
# Processing Record 43 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 44 of Set 8 | kovernino
# Processing Record 45 of Set 8 | puerto leguizamo
# Processing Record 46 of Set 8 | chokwe
# Processing Record 47 of Set 8 | portland
# Processing Record 48 of Set 8 | bolshiye uki
# City not found. Skipping...
# Processing Record 49 of Set 8 | alihe
# Processing Record 50 of Set 8 | luderitz
# Processing Record 1 of Set 9 | tukrah
# Processing Record 2 of Set 9 | merauke
# Processing Record 3 of Set 9 | berlevag
# Processing Record 4 of Set 9 | itoman
# Processing Record 5 of Set 9 | pechora
# Processing Record 6 of Set 9 | vallenar
# Processing Record 7 of Set 9 | pontes e lacerda
# Processing Record 8 of Set 9 | pisco
# Processing Record 9 of Set 9 | senneterre
# Processing Record 10 of Set 9 | kasongo-lunda
# Processing Record 11 of Set 9 | moree
# Processing Record 12 of Set 9 | umm ruwabah
# City not found. Skipping...
# Processing Record 13 of Set 9 | acheng
# Processing Record 14 of Set 9 | yerofey pavlovich
# Processing Record 15 of Set 9 | rincon
# Processing Record 16 of Set 9 | kanelovskaya
# Processing Record 17 of Set 9 | daru
# Processing Record 18 of Set 9 | college
# Processing Record 19 of Set 9 | brigantine
# Processing Record 20 of Set 9 | sambava
# Processing Record 21 of Set 9 | christchurch
# Processing Record 22 of Set 9 | leningradskiy
# Processing Record 23 of Set 9 | waipawa
# Processing Record 24 of Set 9 | reconquista
# Processing Record 25 of Set 9 | tougan
# Processing Record 26 of Set 9 | saint-leu
# Processing Record 27 of Set 9 | nelson bay
# Processing Record 28 of Set 9 | guayaramerin
# Processing Record 29 of Set 9 | selestat
# Processing Record 30 of Set 9 | solnechnyy
# Processing Record 31 of Set 9 | kelo
# Processing Record 32 of Set 9 | lagoa
# Processing Record 33 of Set 9 | iquique
# Processing Record 34 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 9 | robertsport
# Processing Record 36 of Set 9 | cap malheureux
# Processing Record 37 of Set 9 | zielona gora
# Processing Record 38 of Set 9 | ostrovnoy
# Processing Record 39 of Set 9 | ridgecrest
# Processing Record 40 of Set 9 | pochutla
# Processing Record 41 of Set 9 | beringovskiy
# Processing Record 42 of Set 9 | komsomolskiy
# Processing Record 43 of Set 9 | big spring
# Processing Record 44 of Set 9 | labuhan
# Processing Record 45 of Set 9 | ketchikan
# Processing Record 46 of Set 9 | sterling
# Processing Record 47 of Set 9 | matsanga
# City not found. Skipping...
# Processing Record 48 of Set 9 | vila franca do campo
# Processing Record 49 of Set 9 | taoudenni
# Processing Record 50 of Set 9 | plettenberg bay
# Processing Record 1 of Set 10 | verkhoyansk
# Processing Record 2 of Set 10 | jacareacanga
# Processing Record 3 of Set 10 | cayenne
# Processing Record 4 of Set 10 | katra
# Processing Record 5 of Set 10 | cacu
# Processing Record 6 of Set 10 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 10 | vostok
# Processing Record 8 of Set 10 | tessalit
# Processing Record 9 of Set 10 | sokode
# Processing Record 10 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 10 | tandil
# Processing Record 12 of Set 10 | riyadh
# Processing Record 13 of Set 10 | soweto
# Processing Record 14 of Set 10 | nadym
# Processing Record 15 of Set 10 | kieta
# Processing Record 16 of Set 10 | kupang
# Processing Record 17 of Set 10 | along
# Processing Record 18 of Set 10 | yalutorovsk
# Processing Record 19 of Set 10 | mandiana
# Processing Record 20 of Set 10 | lahaina
# Processing Record 21 of Set 10 | batagay-alyta
# Processing Record 22 of Set 10 | morondava
# Processing Record 23 of Set 10 | ilulissat
# Processing Record 24 of Set 10 | tafresh
# Processing Record 25 of Set 10 | bogorodskoye
# Processing Record 26 of Set 10 | bontang
# Processing Record 27 of Set 10 | guerrero negro
# Processing Record 28 of Set 10 | dalvik
# Processing Record 29 of Set 10 | tautira
# Processing Record 30 of Set 10 | urumqi
# Processing Record 31 of Set 10 | san patricio
# Processing Record 32 of Set 10 | broome
# Processing Record 33 of Set 10 | virginia beach
# Processing Record 34 of Set 10 | kokoda
# Processing Record 35 of Set 10 | umm lajj
# Processing Record 36 of Set 10 | mandalgovi
# Processing Record 37 of Set 10 | pyryatyn
# Processing Record 38 of Set 10 | road town
# Processing Record 39 of Set 10 | belaya gora
# Processing Record 40 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 10 | nabire
# Processing Record 42 of Set 10 | sampit
# Processing Record 43 of Set 10 | helong
# Processing Record 44 of Set 10 | oneonta
# Processing Record 45 of Set 10 | lambarene
# Processing Record 46 of Set 10 | mitu
# Processing Record 47 of Set 10 | paamiut
# Processing Record 48 of Set 10 | simplicio mendes
# Processing Record 49 of Set 10 | oistins
# Processing Record 50 of Set 10 | vestmannaeyjar
# Processing Record 1 of Set 11 | huarmey
# Processing Record 2 of Set 11 | santiago
# Processing Record 3 of Set 11 | lodja
# Processing Record 4 of Set 11 | inuvik
# Processing Record 5 of Set 11 | mokolo
# Processing Record 6 of Set 11 | cornwall
# Processing Record 7 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 11 | egvekinot
# Processing Record 9 of Set 11 | tamiahua
# Processing Record 10 of Set 11 | flinders
# Processing Record 11 of Set 11 | qaqortoq
# Processing Record 12 of Set 11 | kandrian
# Processing Record 13 of Set 11 | dahanu
# Processing Record 14 of Set 11 | kargat
# Processing Record 15 of Set 11 | zyryanka
# Processing Record 16 of Set 11 | terrace bay
# Processing Record 17 of Set 11 | camabatela
# Processing Record 18 of Set 11 | kaeo
# Processing Record 19 of Set 11 | duverge
# Processing Record 20 of Set 11 | taiyuan
# Processing Record 21 of Set 11 | sistranda
# Processing Record 22 of Set 11 | sabha
# Processing Record 23 of Set 11 | honningsvag
# Processing Record 24 of Set 11 | hutchinson
# Processing Record 25 of Set 11 | shanghai
# Processing Record 26 of Set 11 | karratha
# Processing Record 27 of Set 11 | itaituba
# Processing Record 28 of Set 11 | saint-joseph
# Processing Record 29 of Set 11 | yumen
# Processing Record 30 of Set 11 | la grande
# Processing Record 31 of Set 11 | yacuiba
# Processing Record 32 of Set 11 | cuiaba
# Processing Record 33 of Set 11 | jiazi
# Processing Record 34 of Set 11 | mantua
# Processing Record 35 of Set 11 | kavaratti
# Processing Record 36 of Set 11 | eyl
# Processing Record 37 of Set 11 | kinsale
# Processing Record 38 of Set 11 | ayagoz
# Processing Record 39 of Set 11 | leh
# Processing Record 40 of Set 11 | makat
# Processing Record 41 of Set 11 | granger
# Processing Record 42 of Set 11 | srednekolymsk
# Processing Record 43 of Set 11 | itamarandiba
# Processing Record 44 of Set 11 | ayr
# Processing Record 45 of Set 11 | rezina
# Processing Record 46 of Set 11 | castelo do piaui
# Processing Record 47 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 11 | beira
# Processing Record 49 of Set 11 | las vegas
# Processing Record 50 of Set 11 | quatre cocos
# Processing Record 1 of Set 12 | la orilla
# Processing Record 2 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 12 | inhambane
# Processing Record 4 of Set 12 | lhokseumawe
# Processing Record 5 of Set 12 | karatuzskoye
# Processing Record 6 of Set 12 | lodwar
# Processing Record 7 of Set 12 | popondetta
# Processing Record 8 of Set 12 | agua prieta
# Processing Record 9 of Set 12 | lebaksiu
# Processing Record 10 of Set 12 | the valley
# Processing Record 11 of Set 12 | kingaroy
# Processing Record 12 of Set 12 | gibara
# Processing Record 13 of Set 12 | beni
# Processing Record 14 of Set 12 | mogadishu
# Processing Record 15 of Set 12 | kununurra
# Processing Record 16 of Set 12 | iracoubo
# Processing Record 17 of Set 12 | krasnyy chikoy
# Processing Record 18 of Set 12 | rawah
# Processing Record 19 of Set 12 | maneadero
# Processing Record 20 of Set 12 | pimenteiras
# Processing Record 21 of Set 12 | sringeri
# Processing Record 22 of Set 12 | apatou
# Processing Record 23 of Set 12 | capao bonito
# Processing Record 24 of Set 12 | naze
# Processing Record 25 of Set 12 | mount gambier
# Processing Record 26 of Set 12 | oussouye
# Processing Record 27 of Set 12 | pierre
# Processing Record 28 of Set 12 | le vauclin
# Processing Record 29 of Set 12 | chilac
# City not found. Skipping...
# Processing Record 30 of Set 12 | kralendijk
# Processing Record 31 of Set 12 | shemonaikha
# Processing Record 32 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 33 of Set 12 | nizhniy odes
# Processing Record 34 of Set 12 | okahandja
# Processing Record 35 of Set 12 | rustenburg
# Processing Record 36 of Set 12 | epe
# Processing Record 37 of Set 12 | berdigestyakh
# Processing Record 38 of Set 12 | charters towers
# Processing Record 39 of Set 12 | anadyr
# Processing Record 40 of Set 12 | port augusta
# Processing Record 41 of Set 12 | oriximina
# Processing Record 42 of Set 12 | foam lake
# Processing Record 43 of Set 12 | wagga wagga
# Processing Record 44 of Set 12 | phimai
# Processing Record 45 of Set 12 | muisne
# Processing Record 46 of Set 12 | bitung
# Processing Record 47 of Set 12 | nagato
# Processing Record 48 of Set 12 | san cristobal
# Processing Record 49 of Set 12 | salinopolis
# Processing Record 50 of Set 12 | jalu
# Processing Record 1 of Set 13 | kirakira
# Processing Record 2 of Set 13 | shingu
# Processing Record 3 of Set 13 | mazamitla
# Processing Record 4 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 13 | micheweni
# Processing Record 6 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 7 of Set 13 | mopipi
# Processing Record 8 of Set 13 | whitehorse
# Processing Record 9 of Set 13 | kushima
# Processing Record 10 of Set 13 | sioux lookout
# Processing Record 11 of Set 13 | svetlogorsk
# Processing Record 12 of Set 13 | san rafael
# Processing Record 13 of Set 13 | tirumullaivasal
# Processing Record 14 of Set 13 | kitale
# Processing Record 15 of Set 13 | biltine
# Processing Record 16 of Set 13 | awbari
# Processing Record 17 of Set 13 | fayaoue
# Processing Record 18 of Set 13 | linxia
# Processing Record 19 of Set 13 | sanming
# Processing Record 20 of Set 13 | hearst
# Processing Record 21 of Set 13 | clarence town
# Processing Record 22 of Set 13 | arcata
# Processing Record 23 of Set 13 | alice springs
# Processing Record 24 of Set 13 | sorong
# Processing Record 25 of Set 13 | killybegs
# Processing Record 26 of Set 13 | steamboat springs
# Processing Record 27 of Set 13 | halkirk
# Processing Record 28 of Set 13 | itamaraju
# Processing Record 29 of Set 13 | meybod
# Processing Record 30 of Set 13 | maldonado
# Processing Record 31 of Set 13 | stornoway
# Processing Record 32 of Set 13 | tuatapere
# Processing Record 33 of Set 13 | te anau
# Processing Record 34 of Set 13 | katobu
# Processing Record 35 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 13 | marilia
# Processing Record 37 of Set 13 | waingapu
# Processing Record 38 of Set 13 | bereda
# Processing Record 39 of Set 13 | palana
# Processing Record 40 of Set 13 | ulaangom
# Processing Record 41 of Set 13 | abnub
# Processing Record 42 of Set 13 | dingle
# Processing Record 43 of Set 13 | westport
# Processing Record 44 of Set 13 | saint-augustin
# Processing Record 45 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 13 | tazovskiy
# Processing Record 47 of Set 13 | cabinda
# Processing Record 48 of Set 13 | nanhai
# Processing Record 49 of Set 13 | kapit
# Processing Record 50 of Set 13 | juneau
# Processing Record 1 of Set 14 | guarumal
# Processing Record 2 of Set 14 | tevriz
# Processing Record 3 of Set 14 | aasiaat
# Processing Record 4 of Set 14 | san lawrenz
# Processing Record 5 of Set 14 | hovd
# Processing Record 6 of Set 14 | punta alta
# Processing Record 7 of Set 14 | yazman
# Processing Record 8 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 10 of Set 14 | castro marim
# Processing Record 11 of Set 14 | atasu
# Processing Record 12 of Set 14 | vao
# Processing Record 13 of Set 14 | madras
# Processing Record 14 of Set 14 | gavle
# Processing Record 15 of Set 14 | erdenet
# Processing Record 16 of Set 14 | shimoda
# Processing Record 17 of Set 14 | chik
# Processing Record 18 of Set 14 | almaznyy
# Processing Record 19 of Set 14 | tangi
# Processing Record 20 of Set 14 | hovezi
# Processing Record 21 of Set 14 | pitimbu
# Processing Record 22 of Set 14 | byron bay
# Processing Record 23 of Set 14 | sao miguel do araguaia
# Processing Record 24 of Set 14 | berbera
# Processing Record 25 of Set 14 | willmar
# Processing Record 26 of Set 14 | oruro
# Processing Record 27 of Set 14 | lumsden
# Processing Record 28 of Set 14 | swan hill
# Processing Record 29 of Set 14 | chute-aux-outardes
# Processing Record 30 of Set 14 | alofi
# Processing Record 31 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 14 | bowen
# Processing Record 33 of Set 14 | campbell river
# Processing Record 34 of Set 14 | moose factory
# Processing Record 35 of Set 14 | tsabong
# Processing Record 36 of Set 14 | algiers
# Processing Record 37 of Set 14 | kemin
# Processing Record 38 of Set 14 | puerto escondido
# Processing Record 39 of Set 14 | bosaso
# Processing Record 40 of Set 14 | rudkobing
# Processing Record 41 of Set 14 | herzogenaurach
# Processing Record 42 of Set 14 | kawasaki
# Processing Record 43 of Set 14 | jiujiang
# Processing Record 44 of Set 14 | joensuu
# Processing Record 45 of Set 14 | ostersund
# Processing Record 46 of Set 14 | cravo norte
# Processing Record 47 of Set 14 | chimore
# Processing Record 48 of Set 14 | muncar
# Processing Record 49 of Set 14 | makakilo city
# Processing Record 50 of Set 14 | ambon
# Processing Record 1 of Set 15 | mayumba
# Processing Record 2 of Set 15 | bairiki
# Processing Record 3 of Set 15 | jinchang
# Processing Record 4 of Set 15 | noumea
# Processing Record 5 of Set 15 | kant
# Processing Record 6 of Set 15 | polunochnoye
# Processing Record 7 of Set 15 | kamloops
# Processing Record 8 of Set 15 | lac du bonnet
# Processing Record 9 of Set 15 | angoram
# Processing Record 10 of Set 15 | el puerto de santa maria
# Processing Record 11 of Set 15 | chipinge
# Processing Record 12 of Set 15 | manadhoo
# Processing Record 13 of Set 15 | ust-kuyga
# Processing Record 14 of Set 15 | chimbote
# Processing Record 15 of Set 15 | wanlaweyn
# Processing Record 16 of Set 15 | coria
# Processing Record 17 of Set 15 | zambezi
# Processing Record 18 of Set 15 | wyndham
# Processing Record 19 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 20 of Set 15 | srandakan
# Processing Record 21 of Set 15 | puttur
# Processing Record 22 of Set 15 | zhaotong
# Processing Record 23 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 24 of Set 15 | toora-khem
# Processing Record 25 of Set 15 | tambura
# Processing Record 26 of Set 15 | vilyuysk
# Processing Record 27 of Set 15 | wamba
# Processing Record 28 of Set 15 | puerto varas
# Processing Record 29 of Set 15 | muroto
# Processing Record 30 of Set 15 | clevelandia
# Processing Record 31 of Set 15 | okato
# Processing Record 32 of Set 15 | nichinan
# Processing Record 33 of Set 15 | bodmin
# Processing Record 34 of Set 15 | khorramshahr
# Processing Record 35 of Set 15 | mareeba
# Processing Record 36 of Set 15 | arona
# Processing Record 37 of Set 15 | manokwari
# Processing Record 38 of Set 15 | sendhwa
# Processing Record 39 of Set 15 | pietersburg
# Processing Record 40 of Set 15 | oksfjord
# Processing Record 41 of Set 15 | tilichiki
# Processing Record 42 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 15 | moroni
# Processing Record 44 of Set 15 | gawler
# Processing Record 45 of Set 15 | nexo
# Processing Record 46 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 47 of Set 15 | filotion
# Processing Record 48 of Set 15 | sol-iletsk
# Processing Record 49 of Set 15 | shakawe
# Processing Record 50 of Set 15 | jiaohe
# Processing Record 1 of Set 16 | balkhash
# Processing Record 2 of Set 16 | jalingo
# Processing Record 3 of Set 16 | coquimbo
# Processing Record 4 of Set 16 | sibolga
# Processing Record 5 of Set 16 | guelengdeng
# City not found. Skipping...
# Processing Record 6 of Set 16 | contamana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weatherpy_df=pd.DataFrame(city_data)
weatherpy_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Bredasdorp -34.5322   20.0403     61.92        72          28
# 1  Cockburn Town  21.4612  -71.1419     84.16        70          40
# 2      Mount Isa -20.7333  139.5000     62.37        63          82
# 3        Vaitape -16.5167 -151.7500     79.29        74          70
# 4       Thompson  55.7435  -97.8558     50.16        62          75
# 5      Busselton -33.6500  115.3333     56.05        69          90
# 6       Cherskiy  68.7500  161.3000     54.66        43           9
# 7          Bluff -46.6000  168.3333     49.80        81          98
# 8        Fortuna  40.5982 -124.1573     59.94        83          56
# 9       Balykshi  47.0667   51.8667     80.60        57          40
#
#    Wind Speed Country                 Date   Current Weather
# 0        3.98      ZA  2021-06-01 15:36:27  scattered clouds
# 1       13.80      TC  2021-06-01 15:26:41  scattered clouds
# 2        5.75      AU  2021-06-01 15:36:28     broken clouds
# 3       15.03      PF  2021-06-01 15:31:09     broken clouds
# 4        4.61      CA  2021-06-01 15:36:28     broken clouds
# 5        4.97      AU  2021-06-01 15:36:28   overcast clouds
# 6        3.00      RU  2021-06-01 15:28:08         clear sky
# 7       19.91      NZ  2021-06-01 15:36:29   overcast clouds
# 8        3.87      US  2021-06-01 15:29:34     broken clouds
# 9       15.66      KZ  2021-06-01 15:36:29  scattered clouds

# %%
#Create the output file (csv)
output_data_file="WeatherPy_Database.csv"
#Export to csv
weatherpy_df.to_csv(output_data_file)
